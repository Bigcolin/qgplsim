# %%
pwd()
# Out:
# "/home/xlx0727/Scripts/Statistic/gplsim/qgplsim"

# %% [markdown]
# # Start

# %%
# run this ceil if source codes was edited
include("DGP.ji")
include("qgplsim.ji")
using Statistics, LinearAlgebra
using LaTeXStrings

import Base.Threads.@threads
# Out:
# WARNING: replacing module qgplsim.

# %% [markdown]
# # QGPLSIM fitting

# %%
# run this ceil for different data sets

α = [1.0, -1.0] # single index for x
θ = [-1.0, 1.0]  # linear for x, <α, θ> = 0 for identification
γ = [1.0, 0.5] # single index for z
β = [1.0, -0.5] # linear for z
# Q(y|x, z) = Xθ + Zβ + g(Xα + Zγ)

n = 500
fx = 1 # y = f(x), fx for different f(x)     
                # fx = 1, y = X*θ + Z*β + (X*α + Z*γ .- 1).^2 + 0.2ϵ
                # fx = 2, y = X*θ + Z*β + log.(1 .+ exp.(X*α + Z*γ .- 1)) + 0.2ϵ
ifz = true # if false, Z = 0, i.e. no category varible
X, Z, y = dgp(n, γ, θ, α, β, fx, ifz)
# p = length(α)
# q = length(γ)
τ = 0.5
# Out:
# 0.5

# %%
# Estimation 

model1 = qgplsim.model(X, Z, y, τ)
alpha_type = 1
# different weight of sum on alpha 
# 0 for true alpha, using α in DGP
# 1 for global: ∑ij sum(Bi - Bj) / n;
# 2 for local: ∑z ∑ij (bzi - bzj) * nz / n;
# when Z = 0, global == local
@time alpha, theta, gamma = qgplsim.estimator(model1, alpha_type)
coefa = 1 / alpha[1]
coefg = 1 / gamma[1]
println("Estimation of index coefs: ")
println("̂α => ", coefa * alpha)
println("̂γ => ", coefg * gamma)

println("Estimation of linear coefs: ")
println("̂θ => ", theta)
println("̂β => ", 0)
# Out:
#   2.554635 seconds (2.57 M allocations: 11.481 GiB, 8.82% gc time)
# Estimation of index coefs:
# ̂α => [0.9999999999999999, -0.8786379337525863]
# ̂γ => [1.0, 0.4870967916636924]
# Estimation of linear coefs:
# ̂θ => [0.08320071756480274 0.09469283577304713]
# ̂β => 0

# %% [markdown]
# # Paths of $g(x \alpha + z \gamma)$ and $\nabla g$
#
# $\alpha = \hat{\alpha}$,
# $z \in S_z$

# %%
using Plots

v = X * alpha # g(Xα + Zγ) => univar func. g(v + zγ) after α was determined and  Z = z
categ, index = model1.categ, model1.index
g, dg = qgplsim.Gz_DGz(v, Z, y) # g: g(v), dg: g'(v)
fig = plot()
for m in 1:6
    vm = v[index[categ[m]]]
    gm = g[index[categ[m]]]
    indm = sortperm(vm)
    sorted_gm = gm[indm]
    sorted_vm = vm[indm]

    plot!(fig, sorted_vm, sorted_gm, label = L"g_{%$m} (v)")

end
fig

# %%
fig = plot()
for m in 1:6
    vm = v[index[categ[m]]]
    dgm = dg[index[categ[m]]]
    indm = sortperm(vm)
    sorted_dgm = dgm[indm]
    sorted_vm = vm[indm]
    plot!(fig, sorted_vm, sorted_dgm, label = L"\nabla g_{%$m} (v)")

end
fig

# %% [markdown]
# # Monte Carlo Simulation

# %% [markdown]
# ## alpha = $\alpha$

# %%
# dorAlphaestimate alpha, using α instead
p = length(α)
# q = length(γ)
Theta0 = zeros(100, p)
Alpha0 = zeros(100, p)
Gamma0 = zeros(100, p)
import Base.Threads.@threads
alpha_type = 0

function MonteCarlo()
    t = time()
    nthreads = 2
    len = Int(100//nthreads)
    @threads for i in 1:nthreads # parallel on threads 
            for j in 1:len # each 25
        X, Z, y = dgp(n, γ, θ, α, β)
        model_ij = qgplsim.model(X, Z, y)

        Alpha0[len*(i - 1) + j, :], Theta0[len*(i - 1) + j, :],Gamma0[len*(i - 1) + j, :] = qgplsim.estimator(model_ij, alpha_type)
        end
    end
    println("MC Computing time: ", time() - t)
    println("Alpha => ", sum(Alpha0, dims = 1))
    println("Theta => ", sum(Theta0, dims = 1))
    println("Gamma => ", sum(Gamma0, dims = 1))
    Alpha0, Theta0, Gamma0
end
Alpha0, Theta0, Gamma0 = MonteCarlo()
size(Alpha0)
# Out:
# MC Computing time: 170.11938405036926
# Alpha => [100.0 -100.0]
# Theta => [40.581846243527515 -42.072744805845986]
# Gamma => [40.63899525139123 20.43278328655007]
# (100, 2)

# %%
var(Alpha0, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.0  0.0

# %%
var(Theta0, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.00786044  0.00891135

# %%
var(Gamma0, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.00206836  0.000536122

# %% [markdown]
# ## alpha = $ \hat{\alpha}_g $

# %%
p = length(α)
# q = length(γ)
Theta1 = zeros(100, p)
Alpha1 = zeros(100, p)
Gamma1 = zeros(100, p)
import Base.Threads.@threads
alpha_type = 1

function MonteCarlo()
    t = time()
    nthreads = 2
    len = Int(100//nthreads)
    @threads for i in 1:nthreads # parallel on threads 
            for j in 1:len # each 25
        X, Z, y = dgp(n, γ, θ, α, β)
        model_ij = qgplsim.model(X, Z, y)

        Alpha1[len*(i - 1) + j, :], Theta1[len*(i - 1) + j, :],Gamma1[len*(i - 1) + j, :] = qgplsim.estimator(model_ij, alpha_type)
        end
    end
    println("MC Computing time: ", time() - t)
    println("Alpha => ", sum(Alpha1, dims = 1))
    println("Theta => ", sum(Theta1, dims = 1))
    println("Gamma => ", sum(Gamma1, dims = 1))
    Alpha, Theta, Gamma
end
Alpha1, Theta1, Gamma1 = MonteCarlo()
size(Alpha1)
# Out:
# MC Computing time: 172.27795696258545
# Alpha => [7.384209869513004 -13.297462047780618]
# Theta => [-19.5594074881741 19.810969431727298]
# Gamma => [38.67534507402338 19.441971219794993]
# (100, 2)

# %%
var(Alpha1, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.0  0.0

# %%
var(Theta1, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.148651  0.175729

# %%
var(Gamma1, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.019391  0.00397289

# %%
set_alpha, index_alpha, most_alpha = qgplsim.collection(sign.(Alpha1))
dc = index_alpha
mc = most_alpha
# Out:
# 2-element Vector{Float64}:
#   1.0
#  -1.0

# %%
rAlpha1 = Alpha1[dc[mc], :]
rTheta1 = Theta1[dc[mc], :]
rGamma1 = Gamma1[dc[mc], :]
ns, = size(rAlpha1)
# Out:
# (48, 2)

# %%
sum(rAlpha1, dims = 1)/ns
# Out:
# 1×2 Matrix{Float64}:
#  0.690319  -0.661589

# %%
sum(rTheta1, dims = 1)/ns
# Out:
# 1×2 Matrix{Float64}:
#  -0.068308  0.0846531

# %%
sum(rGamma1, dims = 1)/ns
# Out:
# 1×2 Matrix{Float64}:
#  0.429669  0.214006

# %%
var(rAlpha1, dims = 1)

# %%
var(rTheta1, dims = 1)

# %%
var(rGamma1, dims = 1)

# %% [markdown]
# ## alpha = $ \hat{\alpha}_l $

# %%
p = length(α)
# q = length(γ)
Theta2 = zeros(100, p)
Alpha2 = zeros(100, p)
Gamma2 = zeros(100, p)
import Base.Threads.@threads
alpha_type = 2

function MonteCarlo()
    t = time()
    nthreads = 2
    len = Int(100//nthreads)
    @threads for i in 1:nthreads # parallel on threads 
            for j in 1:len # each 25
        X, Z, y = dgp(n, γ, θ, α, β)
        model_ij = qgplsim.model(X, Z, y)

        Alpha[len*(i - 1) + j, :], Theta[len*(i - 1) + j, :],Gamma[len*(i - 1) + j, :] = qgplsim.estimator(model_ij, alpha_type)
        end
    end
    println("MC Computing time: ", time() - t)
    println("Alpha => ", sum(Alpha, dims = 1))
    println("Theta => ", sum(Theta, dims = 1))
    println("Gamma => ", sum(Gamma, dims = 1))
    Alpha, Theta, Gamma
end
Alpha, Theta, Gamma = MonteCarlo()
size(Alpha)
# Out:
# MC Computing time: 224.98732709884644
# Alpha => [-1.75813463515334 0.9598412481092313]
# Theta => [-7.747320950514057 12.790546718986874]
# Gamma => [42.115805397371744 21.36628895725654]
# (100, 2)

# %%
var(Gamma, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.00876593  0.00192952

# %%
set_alpha, index_alpha, most_alpha = qgplsim.collection(sign.(Alpha))
dc = index_alpha
mc = most_alpha
# Out:
# 2-element Vector{Float64}:
#  -1.0
#   1.0

# %%
rAlpha = Alpha[dc[-mc], :]
rTheta = Theta[dc[-mc], :]
rGamma = Gamma[dc[-mc], :]
ns, = size(rAlpha)
# Out:
# (47, 2)

# %%
sum(rAlpha, dims = 1)/ns
# Out:
# 1×2 Matrix{Float64}:
#  0.679706  -0.656253

# %%
sum(rTheta, dims = 1)/ns
# Out:
# 1×2 Matrix{Float64}:
#  -0.042049  0.0908408

# %%
sum(rGamma, dims = 1)/ns
# Out:
# 1×2 Matrix{Float64}:
#  0.44562  0.220099

# %%
var(rAlpha, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.0119084  0.0118843

# %%
var(rTheta, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.0242619  0.0284087

# %%
var(rGamma, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.00390722  0.00100872
