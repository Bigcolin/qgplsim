# %%
pwd()
# Out:
# "/home/xlx0727/Scripts/Statistic/qgplsim"

# %% [markdown]
# # Start

# %%
# run this ceil if source codes was edited
include("DGP.ji")
include("qgplsim.ji")
using Statistics, LinearAlgebra
using LaTeXStrings

import Base.Threads.@threads

# %% [markdown]
# # QGPLSIM fitting

# %%
# run this ceil for different data sets

α = [1.0, -1.0] # single index for x
θ = [-1.0, 1.0]  # linear for x, <α, θ> = 0 for identification
γ = [1.0, 0.5] # single index for z
β = [1.0, -0.5] # linear for z
# Q(y|x, z) = Xθ + Zβ + g(Xα + Zγ)

n = 500
fx = 1 # y = f(x), fx for different f(x)     
                # fx = 1, y = X*θ + Z*β + (X*α + Z*γ .- 1).^2 + 0.2ϵ
                # fx = 2, y = X*θ + Z*β + log.(1 .+ exp.(X*α + Z*γ .- 1)) + 0.2ϵ
ifz = true # if false, Z = 0, i.e. no category varible
X, Z, y = dgp(n, γ, θ, α, β, fx, ifz)
# p = length(α)
# q = length(γ)
τ = 0.5
# Out:
# 0.5

# %%
# Estimation 

model1 = qgplsim.model(X, Z, y, τ)
alpha_type = 1
# different weight of sum on alpha 
# 0 for true alpha, using α in DGP
# 1 for global: ∑ij sum(Bi - Bj) / n;
# 2 for local: ∑z ∑ij (bzi - bzj) * nz / n;
# when Z = 0, global == local
@time alpha, theta, gamma = qgplsim.estimator(model1, alpha_type)
coefa = 1 / alpha[1]
coefg = 1 / gamma[1]
println("Estimation of index coefs: ")
println("̂α => ", coefa * alpha)
println("̂γ => ", coefg * gamma)

println("Estimation of linear coefs: ")
println("̂θ => ", theta)
println("̂β => ", 0)
# Out:
#   2.991206 seconds (2.62 M allocations: 13.035 GiB, 17.54% gc time)
# Estimation of index coefs:
# ̂α => [1.0, -1.3450003040459175]
# ̂γ => [1.0, 0.552382711193736]
# Estimation of linear coefs:
# ̂θ => [-0.11123310321763791 -0.08270117328824109]
# ̂β => 0

# %% [markdown]
# # Paths of $g(x \alpha + z \gamma)$ and $\nabla g$
#
# $\alpha = \hat{\alpha}$,
# $z \in S_z$

# %%
using Plots

v = X * alpha # g(Xα + Zγ) => univar func. g(v + zγ) after α was determined and  Z = z
categ, index = model1.categ, model1.index
g, dg = qgplsim.Gz_DGz(v, Z, y) # g: g(v), dg: g'(v)
fig = plot()
for m in 1:6
    vm = v[index[categ[m]]]
    gm = g[index[categ[m]]]
    indm = sortperm(vm)
    sorted_gm = gm[indm]
    sorted_vm = vm[indm]

    plot!(fig, sorted_vm, sorted_gm, label = L"g_{%$m} (v)")

end
fig

# %%
fig = plot()
for m in 1:6
    vm = v[index[categ[m]]]
    dgm = dg[index[categ[m]]]
    indm = sortperm(vm)
    sorted_dgm = dgm[indm]
    sorted_vm = vm[indm]
    plot!(fig, sorted_vm, sorted_dgm, label = L"\nabla g_{%$m} (v)")

end
fig

# %% [markdown]
# # Monte Carlo Simulation

# %% [markdown]
# ## alpha = $\alpha$

# %%
# Do not estimate alpha, using α instead
p = length(α)
# q = length(γ)
Theta0 = zeros(100, p)
Alpha0 = zeros(100, p)
Gamma0 = zeros(100, p)
import Base.Threads.@threads
alpha_type = 0

function MonteCarlo()
    t = time()
    nthreads = 2
    len = Int(100//nthreads)
    @threads for i in 1:nthreads # parallel on threads 
            for j in 1:len # each 25
        X, Z, y = dgp(n, γ, θ, α, β)
        model_ij = qgplsim.model(X, Z, y)

        Alpha0[len*(i - 1) + j, :], Theta0[len*(i - 1) + j, :],Gamma0[len*(i - 1) + j, :] = qgplsim.estimator(model_ij, alpha_type)
        end
    end
    println("MC Computing time: ", time() - t)
    println("Alpha => ", sum(Alpha0, dims = 1))
    println("Theta => ", sum(Theta0, dims = 1))
    println("Gamma => ", sum(Gamma0, dims = 1))
    Alpha0, Theta0, Gamma0
end
Alpha0, Theta0, Gamma0 = MonteCarlo()
size(Alpha0)
# Out:
# MC Computing time: 207.70502519607544
# Alpha => [100.0 -100.0]
# Theta => [40.46991225369917 -43.07406357224363]
# Gamma => [40.530365710447995 20.645198889632827]
# (100, 2)

# %%
var(Alpha0, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.0  0.0

# %%
var(Theta0, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.00842988  0.00804297

# %%
var(Gamma0, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.00218804  0.000553528

# %% [markdown]
# ## alpha = $ \hat{\alpha}_g $

# %%
p = length(α)
# q = length(γ)
Theta1 = zeros(100, p)
Alpha1 = zeros(100, p)
Gamma1 = zeros(100, p)
import Base.Threads.@threads
alpha_type = 1

function MonteCarlo()
    t = time()
    nthreads = 2
    len = Int(100//nthreads)
    @threads for i in 1:nthreads # parallel on threads 
            for j in 1:len # each 25
        X, Z, y = dgp(n, γ, θ, α, β)
        model_ij = qgplsim.model(X, Z, y)

        Alpha1[len*(i - 1) + j, :], Theta1[len*(i - 1) + j, :],Gamma1[len*(i - 1) + j, :] = qgplsim.estimator(model_ij, alpha_type)
        end
    end
    println("MC Computing time: ", time() - t)
    println("Alpha => ", sum(Alpha1, dims = 1))
    println("Theta => ", sum(Theta1, dims = 1))
    println("Gamma => ", sum(Gamma1, dims = 1))
    Alpha1, Theta1, Gamma1
end
Alpha1, Theta1, Gamma1 = MonteCarlo()
size(Alpha1)
# Out:
# MC Computing time: 315.6285150051117
# Alpha => [3.5507129098053802 -5.5871076030569835]
# Theta => [-24.346697820751757 22.8737427380702]
# Gamma => [39.361722442529235 19.0652618145628]
# (100, 2)

# %%
var(Alpha1, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.48768  0.517994

# %%
var(Theta1, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.167485  0.212678

# %%
var(Gamma1, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.0227142  0.00897653

# %%
set_alpha, index_alpha, most_alpha = qgplsim.collection(sign.(Alpha1))
dc = index_alpha
mc = most_alpha
# Out:
# 2-element Vector{Float64}:
#   1.0
#  -1.0

# %%
rAlpha1 = Alpha1[dc[mc], :]
rTheta1 = Theta1[dc[mc], :]
rGamma1 = Gamma1[dc[mc], :]
ns, = size(rAlpha1)
# Out:
# (45, 2)

# %%
sum(rAlpha1, dims = 1)/ns
# Out:
# 1×2 Matrix{Float64}:
#  0.652637  -0.690012

# %%
sum(rTheta1, dims = 1)/ns
# Out:
# 1×2 Matrix{Float64}:
#  -0.102594  0.0866618

# %%
sum(rGamma1, dims = 1)/ns
# Out:
# 1×2 Matrix{Float64}:
#  0.437465  0.224024

# %%
var(rAlpha1, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.0547049  0.0454701

# %%
var(rTheta1, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.108695  0.0885537

# %%
var(rGamma1, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.011626  0.00500978

# %% [markdown]
# ## alpha = $ \hat{\alpha}_l $

# %%
p = length(α)
# q = length(γ)
Theta2 = zeros(100, p)
Alpha2 = zeros(100, p)
Gamma2 = zeros(100, p)
import Base.Threads.@threads
alpha_type = 2

function MonteCarlo()
    t = time()
    nthreads = 2
    len = Int(100//nthreads)
    @threads for i in 1:nthreads # parallel on threads 
            for j in 1:len # each 25
        X, Z, y = dgp(n, γ, θ, α, β)
        model_ij = qgplsim.model(X, Z, y)

        Alpha2[len*(i - 1) + j, :], Theta2[len*(i - 1) + j, :],Gamma2[len*(i - 1) + j, :] = qgplsim.estimator(model_ij, alpha_type)
        end
    end
    println("MC Computing time: ", time() - t)
    println("Alpha => ", sum(Alpha2, dims = 1))
    println("Theta => ", sum(Theta2, dims = 1))
    println("Gamma => ", sum(Gamma2, dims = 1))
    Alpha2, Theta2, Gamma2
end
Alpha2, Theta2, Gamma2 = MonteCarlo()
size(Alpha2)
# Out:
# MC Computing time: 243.12150979042053
# Alpha => [-5.215243482083196 1.0496765718011916]
# Theta => [-7.487040383682339 7.8758333632899005]
# Gamma => [43.020213464243355 21.88696635495499]
# (100, 2)

# %%
var(Gamma2, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.00467511  0.000820361

# %%
set_alpha, index_alpha, most_alpha = qgplsim.collection(sign.(Alpha2))
dc = index_alpha
mc = most_alpha
# Out:
# 2-element Vector{Float64}:
#  -1.0
#   1.0

# %%
rAlpha2 = Alpha2[dc[-mc], :]
rTheta2 = Theta2[dc[-mc], :]
rGamma2 = Gamma2[dc[-mc], :]
ns, = size(rAlpha2)
# Out:
# (47, 2)

# %%
sum(rAlpha2, dims = 1)/ns
# Out:
# 1×2 Matrix{Float64}:
#  0.658628  -0.680271

# %%
sum(rTheta2, dims = 1)/ns
# Out:
# 1×2 Matrix{Float64}:
#  -0.0748247  0.0379789

# %%
sum(rGamma2, dims = 1)/ns
# Out:
# 1×2 Matrix{Float64}:
#  0.432668  0.218949

# %%
var(rAlpha2, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.00889519  0.00697901

# %%
var(rTheta2, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.0186726  0.0124841

# %%
var(rGamma2, dims = 1)
# Out:
# 1×2 Matrix{Float64}:
#  0.00242054  0.00060944
