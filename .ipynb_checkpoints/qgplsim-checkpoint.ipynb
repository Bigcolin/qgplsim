# %%
pwd()
# Out:
# "/home/bigcolin/Scripts/gplsim/quantile/qgplsim"

# %% [markdown]
# # Start

# %%
# run this ceil if source codes was edited
include("DGP.ji")
# include("qgplsim.ji")
include("MonteCarloSIM.ji")
using Statistics, LinearAlgebra, Clustering
using LaTeXStrings, Plots

import Base.Threads.@threads
# Out:
# WARNING: replacing module qgplsim.

# %% [markdown]
# # QGPLSIM fitting

# %%
# run this ceil for different data sets

α = [1.0, 0.5] # single index for x
θ = [1.0, -2.0]  # linear for x, <α, θ> = 0 for identification
γ = [1.00, 0.5] # single index for z
β = [0.5, -1.0] # linear for z
# Q(y|x, z) = Xθ + Zβ + g(Xα + Zγ)

n = 500
fx = 2 # y = f(x), fx for different f(x)     
                # fx = 1, y = X*θ + Z*β + (X*α + Z*γ .- 1).^2 + 0.2ϵ
                # fx = 2, y = X*θ + Z*β + log.(1 .+ exp.(X*α + Z*γ .- 1)) + 0.2ϵ

ifz = true # if false, Z = 0, i.e. no category varible
dist = 1 # 0 for gauss, 1 for Cauchy
X, Z, y = dgp(n, γ, θ, α, β, fx, dist,  ifz)
# p = length(α)
# q = length(γ)
τ = 0.5

# Estimation 

model1 = qgplsim.model(X, Z, y, τ)
alpha_type = 1
# different weight of sum on alpha 
# 0 for true alpha, using α in DGP
# 1 for global: ∑ij sum(Bi - Bj) / n;
# 2 for local: ∑z ∑ij (bzi - bzj) * nz / n;
# when Z = 0, global == local
@time alpha, theta, gamma, beta = qgplsim.estimator(model1, alpha_type)
coefa = 1 #/ alpha[1]
coefg = 1 #/ gamma[1]
println("Estimation of index coefs: ")
println("̂α => ", coefa * alpha)
println("̂γ => ", gamma)

println("Estimation of linear coefs: ")
println("̂θ => ", theta)
println("̂β => ", beta)

# theta * alpha
# Out:
#  16.828005 seconds (3.48 M allocations: 9.859 GiB, 7.68% gc time)
# Estimation of index coefs:
# ̂α => [0.6798691160388488, 0.7333334746597584]
# ̂γ => [0.8711324477458324, 0.508199869389574]
# Estimation of linear coefs:
# ̂θ => [1.6834374528295684 -1.5607048805360297]
# ̂β => [1.1765713527285677, -0.7954692476411356]

# %%
40^(-0.2)
# Out:
# 0.47817624989501845

# %% [markdown]
# # Paths of $g(x \alpha + z \gamma)$ and $\nabla g$
#
# $\alpha = \hat{\alpha}$,
# $z \in S_z$

# %%
using Plots
# include("qgplsim.ji")

# %%
v = X * alpha # g(Xα + Zγ) => univar func. g(v + zγ) after α was determined and  Z = z
categ, index = model1.categ, model1.index
g, dg = qgplsim.Gz_DGz(v, Z, y, -0.2) # g: g(v), dg: g'(v)
fig = plot()
for m in 1:6
    vm = v[index[categ[m]]]
    gm = g[index[categ[m]]]
    indm = sortperm(vm)
    sorted_gm = gm[indm]
    sorted_vm = vm[indm]

    plot!(fig, sorted_vm, sorted_gm, label = L"g_{%$m} (v)")

end
fig

# %%
fig = plot()
for m in 1:6
    vm = v[index[categ[m]]]
    dgm = dg[index[categ[m]]]
    indm = sortperm(vm)
    sorted_dgm = dgm[indm]
    sorted_vm = vm[indm]
    plot!(fig, sorted_vm, sorted_dgm, label = L"\nabla g_{%$m} (v)")

end
fig

# %% [markdown]
# # Monte Carlo Simulation

# %%
Threads.nthreads()
# Out:
# 12

# %%
include("MonteCarloSIM.ji")
# Out:
# WARNING: replacing module qgplsim.
# simulation (generic function with 2 methods)

# %%
α = [1.0, 0.5] # single index for x
θ = [1.0, -2.0]  # linear for x, <α, θ> = 0 for identification
γ = [1.00, 0.5] # single index for z
β = [1.0, -0.5] # linear for z
# Q(y|x, z) = Xθ + Zβ + g(Xα + Zγ)
n = 300
fx = 2
dist = 1 # Cauchy
len = 200 # MC rept. times
alpha_type = 1
# Out:
# 1

# %%
res, Alpha, Gamma, Theta, Beta = MonteCarlo(n, γ, θ, α, β, fx, dist, len, alpha_type)
# Out:
# 0.0%┣                                              ┫ 0/200 [00:00<00:-10, 0s/it]
# 0.5%┣▏                                         ┫ 1/200 [00:06<Inf:Inf, InfGs/it]
# 1.0%┣▌                                              ┫ 2/200 [00:09<28:07, 9s/it]
# 1.5%┣▊                                              ┫ 3/200 [00:11<17:26, 5s/it]
# 2.0%┣█                                              ┫ 4/200 [00:13<14:42, 4s/it]
# 2.5%┣█▏                                             ┫ 5/200 [00:16<12:48, 4s/it]
# 3.0%┣█▍                                             ┫ 6/200 [00:18<11:42, 4s/it]
# 3.5%┣█▋                                             ┫ 7/200 [00:20<10:56, 3s/it]
# 4.0%┣█▉                                             ┫ 8/200 [00:23<10:30, 3s/it]
# 4.5%┣██▏                                            ┫ 9/200 [00:25<10:07, 3s/it]
# 5.0%┣██▎                                           ┫ 10/200 [00:28<09:58, 3s/it]
# 5.5%┣██▌                                           ┫ 11/200 [00:30<09:35, 3s/it]
# 6.0%┣██▊                                           ┫ 12/200 [00:33<09:25, 3s/it]
# 6.5%┣███                                           ┫ 13/200 [00:36<09:14, 3s/it]
# 7.0%┣███▏                                          ┫ 14/200 [00:39<09:11, 3s/it]
# 7.5%┣███▌                                          ┫ 15/200 [00:41<09:00, 3s/it]
# 8.0%┣███▊                                          ┫ 16/200 [00:43<08:47, 3s/it]
# 8.5%┣████                                          ┫ 17/200 [00:46<08:42, 3s/it]
# 9.0%┣████▏                                         ┫ 18/200 [00:48<08:36, 3s/it]
# 9.5%┣████▍                                         ┫ 19/200 [00:51<08:28, 3s/it]
# 10.0%┣████▌                                        ┫ 20/200 [00:53<08:20, 3s/it]
# 10.5%┣████▊                                        ┫ 21/200 [00:55<08:15, 3s/it]
# 11.0%┣█████                                        ┫ 22/200 [00:58<08:11, 3s/it]
# 11.5%┣█████▏                                       ┫ 23/200 [01:00<08:07, 3s/it]
# 12.0%┣█████▍                                       ┫ 24/200 [01:03<08:03, 3s/it]
# 12.5%┣█████▋                                       ┫ 25/200 [01:06<07:58, 3s/it]
# 13.0%┣█████▉                                       ┫ 26/200 [01:08<07:55, 3s/it]
# 13.5%┣██████                                       ┫ 27/200 [01:11<07:50, 3s/it]
# 14.0%┣██████▎                                      ┫ 28/200 [01:13<07:45, 3s/it]
# 14.5%┣██████▌                                      ┫ 29/200 [01:16<07:45, 3s/it]
# 15.0%┣██████▊                                      ┫ 30/200 [01:18<07:40, 3s/it]
# 15.5%┣███████                                      ┫ 31/200 [01:21<07:36, 3s/it]
# 16.0%┣███████▏                                     ┫ 32/200 [01:23<07:31, 3s/it]
# 16.5%┣███████▍                                     ┫ 33/200 [01:26<07:31, 3s/it]
# 17.0%┣███████▋                                     ┫ 34/200 [01:29<07:27, 3s/it]
# 17.5%┣███████▉                                     ┫ 35/200 [01:31<07:22, 3s/it]
# 18.0%┣████████                                     ┫ 36/200 [01:34<07:18, 3s/it]
# 18.5%┣████████▎                                    ┫ 37/200 [01:36<07:16, 3s/it]
# 19.0%┣████████▌                                    ┫ 38/200 [01:39<07:13, 3s/it]
# 19.5%┣████████▊                                    ┫ 39/200 [01:42<07:10, 3s/it]
# 20.0%┣█████████                                    ┫ 40/200 [01:44<07:07, 3s/it]
# 20.5%┣█████████▎                                   ┫ 41/200 [01:46<07:03, 3s/it]
# 21.0%┣█████████▌                                   ┫ 42/200 [01:49<07:01, 3s/it]
# 21.5%┣█████████▊                                   ┫ 43/200 [01:52<06:58, 3s/it]
# 22.0%┣██████████                                   ┫ 44/200 [01:54<06:54, 3s/it]
# 22.5%┣██████████▏                                  ┫ 45/200 [01:57<06:52, 3s/it]
# 23.0%┣██████████▍                                  ┫ 46/200 [01:59<06:48, 3s/it]
# 23.5%┣██████████▋                                  ┫ 47/200 [02:02<06:45, 3s/it]
# 24.0%┣██████████▉                                  ┫ 48/200 [02:04<06:42, 3s/it]
# 24.5%┣███████████                                  ┫ 49/200 [02:06<06:38, 3s/it]
# 25.0%┣███████████▎                                 ┫ 50/200 [02:09<06:34, 3s/it]
# 25.5%┣███████████▌                                 ┫ 51/200 [02:11<06:31, 3s/it]
# 26.0%┣███████████▊                                 ┫ 52/200 [02:14<06:28, 3s/it]
# 26.5%┣████████████                                 ┫ 53/200 [02:17<06:27, 3s/it]
# 27.0%┣████████████▏                                ┫ 54/200 [02:19<06:24, 3s/it]
# 27.5%┣████████████▍                                ┫ 55/200 [02:22<06:21, 3s/it]
# 28.0%┣████████████▋                                ┫ 56/200 [02:24<06:18, 3s/it]
# 28.5%┣████████████▉                                ┫ 57/200 [02:27<06:15, 3s/it]
# 29.0%┣█████████████                                ┫ 58/200 [02:29<06:12, 3s/it]
# 29.5%┣█████████████▎                               ┫ 59/200 [02:32<06:09, 3s/it]
# 30.0%┣█████████████▌                               ┫ 60/200 [02:35<06:07, 3s/it]
# 30.5%┣█████████████▊                               ┫ 61/200 [02:37<06:03, 3s/it]
# 31.0%┣██████████████                               ┫ 62/200 [02:39<06:00, 3s/it]
# 31.5%┣██████████████▏                              ┫ 63/200 [02:41<05:56, 3s/it]
# 32.0%┣██████████████▍                              ┫ 64/200 [02:44<05:53, 3s/it]
# 32.5%┣██████████████▋                              ┫ 65/200 [02:46<05:51, 3s/it]
# 33.0%┣██████████████▉                              ┫ 66/200 [02:49<05:48, 3s/it]
# 33.5%┣███████████████                              ┫ 67/200 [02:51<05:46, 3s/it]
# 34.0%┣███████████████▎                             ┫ 68/200 [02:54<05:43, 3s/it]
# 34.5%┣███████████████▌                             ┫ 69/200 [02:57<05:41, 3s/it]
# 35.0%┣███████████████▊                             ┫ 70/200 [03:00<05:38, 3s/it]
# 35.5%┣████████████████                             ┫ 71/200 [03:03<05:36, 3s/it]
# 36.0%┣████████████████▏                            ┫ 72/200 [03:05<05:34, 3s/it]
# 36.5%┣████████████████▍                            ┫ 73/200 [03:07<05:30, 3s/it]
# 37.0%┣████████████████▋                            ┫ 74/200 [03:10<05:28, 3s/it]
# 37.5%┣████████████████▉                            ┫ 75/200 [03:12<05:25, 3s/it]
# 38.0%┣█████████████████                            ┫ 76/200 [03:15<05:22, 3s/it]
# 38.5%┣█████████████████▎                           ┫ 77/200 [03:17<05:19, 3s/it]
# 39.0%┣█████████████████▌                           ┫ 78/200 [03:20<05:17, 3s/it]
# 39.5%┣█████████████████▊                           ┫ 79/200 [03:23<05:15, 3s/it]
# 40.0%┣██████████████████                           ┫ 80/200 [03:26<05:13, 3s/it]
# 40.5%┣██████████████████▎                          ┫ 81/200 [03:29<05:10, 3s/it]
# 41.0%┣██████████████████▌                          ┫ 82/200 [03:31<05:07, 3s/it]
# 41.5%┣██████████████████▊                          ┫ 83/200 [03:34<05:05, 3s/it]
# 42.0%┣███████████████████                          ┫ 84/200 [03:37<05:03, 3s/it]
# 42.5%┣███████████████████▏                         ┫ 85/200 [03:39<05:00, 3s/it]
# 43.0%┣███████████████████▍                         ┫ 86/200 [03:42<04:58, 3s/it]
# 43.5%┣███████████████████▋                         ┫ 87/200 [03:44<04:55, 3s/it]
# 44.0%┣███████████████████▉                         ┫ 88/200 [03:47<04:52, 3s/it]
# 44.5%┣████████████████████                         ┫ 89/200 [03:50<04:50, 3s/it]
# 45.0%┣████████████████████▎                        ┫ 90/200 [03:52<04:47, 3s/it]
# 45.5%┣████████████████████▌                        ┫ 91/200 [03:54<04:44, 3s/it]
# 46.0%┣████████████████████▊                        ┫ 92/200 [03:56<04:41, 3s/it]
# 46.5%┣█████████████████████                        ┫ 93/200 [03:59<04:38, 3s/it]
# 47.0%┣█████████████████████▏                       ┫ 94/200 [04:02<04:36, 3s/it]
# 47.5%┣█████████████████████▍                       ┫ 95/200 [04:04<04:33, 3s/it]
# 48.0%┣█████████████████████▋                       ┫ 96/200 [04:07<04:31, 3s/it]
# 48.5%┣█████████████████████▉                       ┫ 97/200 [04:10<04:28, 3s/it]
# 49.0%┣██████████████████████                       ┫ 98/200 [04:12<04:25, 3s/it]
# 49.5%┣██████████████████████▎                      ┫ 99/200 [04:14<04:22, 3s/it]
# 50.0%┣██████████████████████                      ┫ 100/200 [04:16<04:19, 3s/it]
# 50.5%┣██████████████████████▏                     ┫ 101/200 [04:18<04:16, 3s/it]
# 51.0%┣██████████████████████▍                     ┫ 102/200 [04:21<04:14, 3s/it]
# 51.5%┣██████████████████████▋                     ┫ 103/200 [04:23<04:10, 3s/it]
# 52.0%┣██████████████████████▉                     ┫ 104/200 [04:25<04:07, 3s/it]
# 52.5%┣███████████████████████                     ┫ 105/200 [04:28<04:05, 3s/it]
# 53.0%┣███████████████████████▎                    ┫ 106/200 [04:30<04:02, 3s/it]
# 53.5%┣███████████████████████▌                    ┫ 107/200 [04:33<03:59, 3s/it]
# 54.0%┣███████████████████████▊                    ┫ 108/200 [04:35<03:56, 3s/it]
# 54.5%┣████████████████████████                    ┫ 109/200 [04:37<03:54, 3s/it]
# 55.0%┣████████████████████████▏                   ┫ 110/200 [04:40<03:51, 3s/it]
# 55.5%┣████████████████████████▍                   ┫ 111/200 [04:42<03:48, 3s/it]
# 56.0%┣████████████████████████▋                   ┫ 112/200 [04:45<03:46, 3s/it]
# 56.5%┣████████████████████████▉                   ┫ 113/200 [04:47<03:43, 3s/it]
# 57.0%┣█████████████████████████                   ┫ 114/200 [04:50<03:40, 3s/it]
# 57.5%┣█████████████████████████▎                  ┫ 115/200 [04:52<03:38, 3s/it]
# 58.0%┣█████████████████████████▌                  ┫ 116/200 [04:54<03:35, 3s/it]
# 58.5%┣█████████████████████████▊                  ┫ 117/200 [04:56<03:32, 3s/it]
# 59.0%┣██████████████████████████                  ┫ 118/200 [04:58<03:29, 3s/it]
# 59.5%┣██████████████████████████▏                 ┫ 119/200 [05:01<03:27, 3s/it]
# 60.0%┣██████████████████████████▍                 ┫ 120/200 [05:03<03:24, 3s/it]
# 60.5%┣██████████████████████████▋                 ┫ 121/200 [05:05<03:21, 3s/it]
# 61.0%┣██████████████████████████▉                 ┫ 122/200 [05:07<03:18, 3s/it]
# 61.5%┣███████████████████████████                 ┫ 123/200 [05:10<03:16, 3s/it]
# 62.0%┣███████████████████████████▎                ┫ 124/200 [05:12<03:13, 3s/it]
# 62.5%┣███████████████████████████▌                ┫ 125/200 [05:14<03:10, 3s/it]
# 63.0%┣███████████████████████████▊                ┫ 126/200 [05:17<03:08, 3s/it]
# 63.5%┣████████████████████████████                ┫ 127/200 [05:19<03:05, 3s/it]
# 64.0%┣████████████████████████████▏               ┫ 128/200 [05:22<03:02, 3s/it]
# 64.5%┣████████████████████████████▍               ┫ 129/200 [05:24<02:59, 3s/it]
# 65.0%┣████████████████████████████▋               ┫ 130/200 [05:26<02:57, 3s/it]
# 65.5%┣████████████████████████████▉               ┫ 131/200 [05:29<02:54, 3s/it]
# 66.0%┣█████████████████████████████               ┫ 132/200 [05:31<02:52, 3s/it]
# 66.5%┣█████████████████████████████▎              ┫ 133/200 [05:34<02:49, 3s/it]
# 67.0%┣█████████████████████████████▌              ┫ 134/200 [05:36<02:47, 3s/it]
# 67.5%┣█████████████████████████████▊              ┫ 135/200 [05:39<02:44, 3s/it]
# 68.0%┣██████████████████████████████              ┫ 136/200 [05:41<02:42, 3s/it]
# 68.5%┣██████████████████████████████▏             ┫ 137/200 [05:43<02:39, 3s/it]
# 69.0%┣██████████████████████████████▍             ┫ 138/200 [05:46<02:37, 3s/it]
# 69.5%┣██████████████████████████████▋             ┫ 139/200 [05:48<02:34, 3s/it]
# 70.0%┣██████████████████████████████▉             ┫ 140/200 [05:50<02:31, 3s/it]
# 70.5%┣███████████████████████████████             ┫ 141/200 [05:53<02:29, 3s/it]
# 71.0%┣███████████████████████████████▎            ┫ 142/200 [05:56<02:26, 3s/it]
# 71.5%┣███████████████████████████████▌            ┫ 143/200 [05:59<02:24, 3s/it]
# 72.0%┣███████████████████████████████▊            ┫ 144/200 [06:02<02:22, 3s/it]
# 72.5%┣████████████████████████████████            ┫ 145/200 [06:05<02:20, 3s/it]
# 73.0%┣████████████████████████████████▏           ┫ 146/200 [06:08<02:17, 3s/it]
# 73.5%┣████████████████████████████████▍           ┫ 147/200 [06:11<02:15, 3s/it]
# 74.0%┣████████████████████████████████▋           ┫ 148/200 [06:14<02:12, 3s/it]
# 74.5%┣████████████████████████████████▉           ┫ 149/200 [06:17<02:10, 3s/it]
# 75.0%┣█████████████████████████████████           ┫ 150/200 [06:20<02:08, 3s/it]
# 75.5%┣█████████████████████████████████▏          ┫ 151/200 [06:23<02:05, 3s/it]
# 76.0%┣█████████████████████████████████▍          ┫ 152/200 [06:26<02:03, 3s/it]
# 76.5%┣█████████████████████████████████▋          ┫ 153/200 [06:29<02:00, 3s/it]
# 77.0%┣█████████████████████████████████▉          ┫ 154/200 [06:32<01:58, 3s/it]
# 77.5%┣██████████████████████████████████          ┫ 155/200 [06:35<01:55, 3s/it]
# 78.0%┣██████████████████████████████████▎         ┫ 156/200 [06:38<01:53, 3s/it]
# 78.5%┣██████████████████████████████████▌         ┫ 157/200 [06:41<01:51, 3s/it]
# 79.0%┣██████████████████████████████████▊         ┫ 158/200 [06:43<01:48, 3s/it]
# 79.5%┣███████████████████████████████████         ┫ 159/200 [06:46<01:45, 3s/it]
# 80.0%┣███████████████████████████████████▏        ┫ 160/200 [06:50<01:43, 3s/it]
# 80.5%┣███████████████████████████████████▍        ┫ 161/200 [06:53<01:41, 3s/it]
# 81.0%┣███████████████████████████████████▋        ┫ 162/200 [06:55<01:38, 3s/it]
# 81.5%┣███████████████████████████████████▉        ┫ 163/200 [06:58<01:35, 3s/it]
# 82.0%┣████████████████████████████████████        ┫ 164/200 [07:01<01:33, 3s/it]
# 82.5%┣████████████████████████████████████▎       ┫ 165/200 [07:03<01:30, 3s/it]
# 83.0%┣████████████████████████████████████▌       ┫ 166/200 [07:07<01:28, 3s/it]
# 83.5%┣████████████████████████████████████▊       ┫ 167/200 [07:10<01:25, 3s/it]
# 84.0%┣█████████████████████████████████████       ┫ 168/200 [07:12<01:23, 3s/it]
# 84.5%┣█████████████████████████████████████▏      ┫ 169/200 [07:16<01:20, 3s/it]
# 85.0%┣█████████████████████████████████████▍      ┫ 170/200 [07:20<01:18, 3s/it]
# 85.5%┣█████████████████████████████████████▋      ┫ 171/200 [07:23<01:16, 3s/it]
# 86.0%┣█████████████████████████████████████▉      ┫ 172/200 [07:26<01:13, 3s/it]
# 86.5%┣██████████████████████████████████████      ┫ 173/200 [07:29<01:10, 3s/it]
# 87.0%┣██████████████████████████████████████▎     ┫ 174/200 [07:32<01:08, 3s/it]
# 87.5%┣██████████████████████████████████████▌     ┫ 175/200 [07:35<01:05, 3s/it]
# 88.0%┣██████████████████████████████████████▊     ┫ 176/200 [07:39<01:03, 3s/it]
# 88.5%┣███████████████████████████████████████     ┫ 177/200 [07:42<01:00, 3s/it]
# 89.0%┣███████████████████████████████████████▏    ┫ 178/200 [07:45<00:58, 3s/it]
# 89.5%┣███████████████████████████████████████▍    ┫ 179/200 [07:48<00:55, 3s/it]
# 90.0%┣███████████████████████████████████████▋    ┫ 180/200 [07:51<00:53, 3s/it]
# 90.5%┣███████████████████████████████████████▉    ┫ 181/200 [07:54<00:50, 3s/it]
# 91.0%┣████████████████████████████████████████    ┫ 182/200 [07:56<00:47, 3s/it]
# 91.5%┣████████████████████████████████████████▎   ┫ 183/200 [07:59<00:45, 3s/it]
# 92.0%┣████████████████████████████████████████▌   ┫ 184/200 [08:02<00:42, 3s/it]
# 92.5%┣████████████████████████████████████████▊   ┫ 185/200 [08:05<00:40, 3s/it]
# 93.0%┣█████████████████████████████████████████   ┫ 186/200 [08:09<00:37, 3s/it]
# 93.5%┣█████████████████████████████████████████▏  ┫ 187/200 [08:12<00:34, 3s/it]
# 94.0%┣█████████████████████████████████████████▍  ┫ 188/200 [08:14<00:32, 3s/it]
# 94.5%┣█████████████████████████████████████████▋  ┫ 189/200 [08:17<00:29, 3s/it]
# 95.0%┣█████████████████████████████████████████▉  ┫ 190/200 [08:19<00:26, 3s/it]
# 95.5%┣██████████████████████████████████████████  ┫ 191/200 [08:22<00:24, 3s/it]
# 96.0%┣██████████████████████████████████████████▎ ┫ 192/200 [08:25<00:21, 3s/it]
# 96.5%┣██████████████████████████████████████████▌ ┫ 193/200 [08:28<00:19, 3s/it]
# 97.0%┣██████████████████████████████████████████▊ ┫ 194/200 [08:32<00:16, 3s/it]
# 97.5%┣███████████████████████████████████████████ ┫ 195/200 [08:35<00:13, 3s/it]
# 98.0%┣███████████████████████████████████████████▏┫ 196/200 [08:38<00:11, 3s/it]
# 98.5%┣███████████████████████████████████████████▍┫ 197/200 [08:40<00:08, 3s/it]
# 99.0%┣███████████████████████████████████████████▋┫ 198/200 [08:43<00:05, 3s/it]
# 99.5%┣███████████████████████████████████████████▉┫ 199/200 [08:46<00:03, 3s/it]
# 100.0%┣███████████████████████████████████████████┫ 200/200 [08:49<00:00, 3s/it]
# 100.0%┣███████████████████████████████████████████┫ 200/200 [08:49<00:00, 3s/it]
# (Dict(:var_β2 => 0.616341385951152,:α1 => -0.0018057661136520636,:γ1 => 0.02195339003756106,:var_α2 => 0.2920614579419202,:γ2 => -0.015373682505315607,:θ1 => 1.0734343028102706,:var_γ2 => 0.3681586620593652,:α2 => 0.04594986607016488,:β1 => 1.2334023986579754,:var_γ1 => 1.2827015929883077…), [0.8639821430785869 -0.03119775457975988 0.502555028380488; 0.8570160429162595 0.43850049843565897 0.2706304030515315; … ; -0.8603019268491009 -0.4903473659723639 0.13942759893108894; 0.9760462382446929 0.09874494400103948 0.19386381003842743], [1.215425301699269 0.5238145342361561; 0.883252037913529 0.6502192702688708; … ; -1.094516129746273 -0.882395391693772; 0.7872797544333383 0.13812861778031188], [1.1825536663322627 -0.6912857522847787 -2.0759354802387633; 1.0899740828390574 -0.8930792686282307 -2.0046142813328878; … ; 0.47846413767310425 -1.329627768212069 -1.7238757329309686; 0.5000682796242577 -0.8542332123061221 -2.08258855739876], [1.1933515570288524 -0.3997968630230068; 0.4724951958018218 -0.9836700479339454; … ; 0.4918478090375547 -1.3095222769310126; 1.0710731331997647 -0.3448745647366511])

# %%
histogram(Theta[:,3], bins = -3:0.2:3)

# %%
histogram(Gamma[:,1], bins = -2:0.2:2)

# %%
histogram(abs.(Gamma[:,1]), bins = 0:0.2:2)

# %%
histogram(Gamma[:,2], bins = -2:0.2:2)

# %%
histogram(abs.(Gamma[:,2]), bins = -2:0.2:2)

# %%
Rg = kmeans(transpose(Gamma), 2)
Rg.centers
# Out:
# 2×2 Array{Float64,2}:
#  1.01251   -0.948989
#  0.421648  -0.443742

# %%
t = randn(100) *3
var(t)
# Out:
# 10.647726714457002

# %%
ind1 = Rg.assignments .== 1
ind2 = Rg.assignments .== 2
v1 = var(Gamma[ind1, :], dims = 1)
# Out:
# 1×2 Array{Float64,2}:
#  0.310815  0.165007

# %%
v2 = var(Gamma[ind2, :], dims = 1)
# Out:
# 1×2 Array{Float64,2}:
#  0.32443  0.196516

# %%
len1 = sum(ind1) - 1
len2 = sum(ind2) - 1
# Out:
# 100

# %%
(v1 * len1 + v2* len2) /(len - 1)
# Out:
# 1×2 Array{Float64,2}:
#  0.316095  0.180012

# %%
var(abs.(Gamma), dims = 1)
# Out:
# 1×2 Array{Float64,2}:
#  0.29951  0.0891436

# %%
g1 = sum(Rg.assignments .== 1)
g2 = 200 - g1
# Out:
# 107

# %%
(g2 * Rg.centers[:, 2] -  g1 * Rg.centers[:, 1] ) / 200
# Out:
# 2-element Array{Float64,1}:
#  0.7445073464997245
#  0.9359496665289737

# %%
histogram(Alpha[:,1], bins = -2:0.2:2)

# %%
histogram(Alpha[:,2], bins = -2:0.2:2)

# %%
Ra= kmeans(transpose(Alpha), 2)
Ra.centers
# Out:
# 3×2 Array{Float64,2}:
#  -0.543466  0.529129
#  -0.21783   0.304507
#  -0.249278  0.204168

# %%
a1 = sum(Ra.assignments .== 1)
a2 = 200 - a1
# Out:
# 101

# %%
(a2 * Ra.centers[:, 2] -  a1 * Ra.centers[:, 1] ) / 200
# Out:
# 3-element Array{Float64,1}:
#  0.53622578750925
#  0.2616020529549162
#  0.226497242879086

# %%
using DataFrames
df = DataFrame(α1 = Float64[], α2 = Float64[],
               var_α1 = Float64[], var_α2 = Float64[],    
               θ1 = Float64[], θ2 = Float64[],
               var_θ1 = Float64[], var_θ2 = Float64[], 
               β1 = Float64[], β2 = Float64[],
               var_β1 = Float64[], var_β2 = Float64[], 
               γ1 = Float64[], γ2 = Float64[],
               var_γ1 = Float64[], var_γ2 = Float64[])
# Out:
# 0×16 DataFrame

# %%
A = [:α1, :α2, :var_α1, :var_α2]
T = [:θ1, :θ2, :var_θ1, :var_θ2]
G = [:γ1, :γ2, :var_γ1, :var_γ2]
B = [:β1, :β2, :var_β1, :var_β2]
# Out:
# 4-element Vector{Symbol}:
#  :β1
#  :β2
#  :var_β1
#  :var_β2

# %%
@threads for γ in [[1.0, 0.5], [1.0, 0.001], [0.001, 1.0], [0.5, 1.0],[0.5, 0.5], [0.0001, 0.0001]]
    res, =  MonteCarlo(n, γ, θ, α, β, fx, dist, len, alpha_type)
    push!(df, res)
end
