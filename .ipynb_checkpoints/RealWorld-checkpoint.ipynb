# %% [markdown]
# # Car-mpg

# %%
using Plots, PyCall, PyPlot
@pyimport seaborn as sns
@pyimport pandas as pd
# Out:
# WARNING: using PyPlot.spy in module Main conflicts with an existing identifier.
# WARNING: using PyPlot.plot in module Main conflicts with an existing identifier.
# WARNING: using PyPlot.savefig in module Main conflicts with an existing identifier.
# WARNING: using PyPlot.scatter in module Main conflicts with an existing identifier.
# /home/kyan/DevTools/Miniconda3/envs/stats/lib/python3.9/inspect.py:351: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   value = getattr(object, key)
# /home/kyan/DevTools/Miniconda3/envs/stats/lib/python3.9/inspect.py:351: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   value = getattr(object, key)
# /home/kyan/DevTools/Miniconda3/envs/stats/lib/python3.9/inspect.py:351: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   value = getattr(object, key)

# %% [markdown]
# ## Carmpg dataset

# %%
df = pd.read_csv("../Datasets/auto-mpg.csv")
sns.pairplot(df)
# Out:
# Figure(PyObject <Figure size 1750x1750 with 56 Axes>)
# PyObject <seaborn.axisgrid.PairGrid object at 0x7f425d3fa820>

# %% [markdown]
# ## 可以看到，cylinders 和 origin  这两个分类变量对应变量mpg是有影响的，考虑到样本容量只有392，这里将类别较少的 origin 放入模型；
#
# ## 连续变量则考虑 displacement, weight, model year, horsepower，

# %%
## data pre-process"
include("RealWorldData.ji")

X, Z, y, zmap = get_cardata()
Hy = maximum(y) - minimum(y) 
y = y ./Hy
y = y .- mean(y)

histogram(y)
# Out:
# WARNING: replacing module qgplsim.

# %% [markdown]
# 这里对y进行了放缩，实验中发现如果不这么做离散项的估计就很差；
#
# 应该是因为$\gamma$的估计方法，其要求$z$取不同值时, 对应的函数曲线距离不能太大

# %%
zmap
# Out:
# 1-element Vector{Any}:
#  Dict{Any, Any}(2 => [0, 0], 3 => [0, 1], 1 => [1, 0])

# %% [markdown]
# origin 的三个不同取值的映射

# %% [markdown]
# ## PLSIQR fitting

# %%
X, Z_origin, y, zmap = get_cardata()
Hy = maximum(y) - minimum(y) 
y = y ./Hy
y = y .- mean(y)
width_exp = -0.2
# Out:
# -0.2

# %%
Z = Z_origin .* 0.1
nfold = 4
index_test, index_train = nsplit_z(Z, nfold)
Alpha = []
Theta = []
Beta = []
Gamma = []
tau = [0.5]
for k in 1:nfold
    indt, indr = index_test[k], index_train[k]
    Xr, Zr, yr = X[indr, :], Z[indr, :], y[indr] 
    Xt, Zt, yt = X[indt, :], Z[indt, :], y[indt]
    carmodel = qgplsim.model(Xr, Zr, yr, tau, width_exp)
    qgplsim.estimator(carmodel)
    qgplsim.print_model(carmodel)
    ylx = Xt * carmodel.alpha
    ylz = Zt * carmodel.beta
    gv = qgplsim.predict(carmodel, Xt, Zt)
    yp = (gv + ylx + ylz)
    push!(Alpha, carmodel.alpha)
    push!(Beta, carmodel.beta)
    push!(Theta, carmodel.theta)
    push!(Gamma, carmodel.gamma)
    println("rmse of fold $k: ", rmsd(yp, yt) * Hy, "\n")
end
# Out:
# alpha => [-0.0488, -0.124, -0.0298, 0.053]
# theta => [0.9199, -0.3774, -0.0728, -0.0779]
# gamma => [-0.0082, 0.0082]
# beta => [0.0135, 0.9951]
# rmse of fold 1: 3.3618850667788913
#
# alpha => [-0.026, -0.1272, -0.0265, 0.0408]
# theta => [0.9677, -0.1992, -0.1271, -0.0878]
# gamma => [0.1298, 0.2821]
# beta => [-0.2247, -0.0473]
# rmse of fold 2: 3.0784864747964247
#
# alpha => [-0.0299, -0.085, -0.0393, 0.0412]
# theta => [0.9167, -0.3878, 0.0694, -0.0672]
# gamma => [0.037, -0.4087]
# beta => [-0.0562, 0.013]
# rmse of fold 3: 3.665551714064802
#
# alpha => [-0.0283, -0.1177, -0.0561, 0.0518]
# theta => [0.9625, -0.17, -0.1977, -0.0742]
# gamma => [0.3104, 0.4867]
# beta => [-0.034, 0.023]
# rmse of fold 4: 3.052213780402094

# %%
alpha_, theta_, beta_, gamma_ = mean(Alpha), mean(Theta), mean(Beta), mean(Gamma)
beta_
# Out:
# 2-element Vector{Float64}:
#  -0.07535138993349619
#   0.24593532729876652

# %%
gamma_
# Out:
# 2-element Vector{Float64}:
#  0.11722720572327441
#  0.09208465506223236

# %%
# indr, indt = get_train_index(Z, 294)
# Xr, Zr, yr = X[indr, :], Z[indr, :], y[indr]
# Xt, Zt, yt = X[indt, :], Z[indt, :], y[indt]
car_model = qgplsim.model(X, Z, y, tau, width_exp)
car_model.alpha, car_model.theta, car_model.beta, car_model.gamma = alpha_, theta_, beta_, gamma_ 
ylx = X * car_model.alpha
ylz = Z * car_model.beta
gv = qgplsim.predict(car_model, X, Z)
yp = gv + ylx + ylz  
rmsd(yp, y) * Hy
# Out:
# 3.147682633919547

# %% [markdown]
# ## 单次实验，测试集预测的结果与真实值的对比

# %%
using LaTeXStrings
e = round(rmsd(yp, y), digits = 4)
str = string(L"||\hat{y} - y||_2 = ", "$e")
histogram(y .- yp, label = L"\hat{y} - y")
xlabel!(str)

# %% [markdown]
# ## 分类变量$z_i$, $i = 1,2,3$， 非参部分估计的在$q = 0.5$时的拟合曲线

# %%
categ, index = collection(Z)
ncateg = length(categ)
fig = plot(layouts = (1,ncateg))

# %%
str_label = [L"g(v|z_1)", L"g(v|z_2)", L"g(v|z_3)"]
vv = X * car_model.theta + Z * car_model.gamma
for k in 1:ncateg
    pk = fig.subplots[k]
    zk = categ[k]
    indk = index[zk]
    
    vk = vv[indk] * -(1)^(k + 1)
    ypk = gv[indk] * Hy   
    ytk = (y[indk] - ylx[indk] - ylz[indk]) * Hy

    sort_ind = sortperm(vk)

    scatter!(pk, vk, ytk, label = false)
    plot!(pk, vk[sort_ind], ypk[sort_ind], width = 2, label = str_label[k])


end

xlabel!(fig[2], L"u = X \theta + Z \gamma")
plot!(size = (800, 500))
# Plots.savefig("gv_qr.png")
fig

# %%
categ, index = collection(Z)
vv = X * car_model.theta + Z * car_model.gamma
ncateg = length(categ)

fig = plot(layouts = (1,3))
categ, index = collection(Z)

mave_model = semiMAVE.model(X, Z, y) 
mave_model.β, mave_model.θ = beta_mave, theta_mave   
gvm, = semiMAVE.predictor(mave_model, X, Z)
vv = X * theta_mave
ylz_mave = Z * beta_mave
str_label = [L"g(v|z_1)", L"g(v|z_2)", L"g(v|z_3)"]
for k in 1:3
    pk = fig.subplots[k]
    zk = categ[k]
    indk = index[zk]
    
    vk = vv[indk] # * -(1)^(k + 1)
    ypk = gvm[indk] * Hy   
    ytk = (y[indk] - ylz_mave[indk]) * Hy

    sort_ind = sortperm(vk)

    scatter!(pk, vk, ytk, label = false)
    plot!(pk, vk[sort_ind], ypk[sort_ind], width = 2, label = str_label[k])


end

xlabel!(fig[2], L"u = X \theta + Z \gamma")
plot!(size = (800, 500))
# Plots.savefig("gv_mave.png")
fig

# %% [markdown]
# ## Monte Carlo: compared with a semi-mave method from Xia. (2006)

# %%
include("./src/semi_mave.ji")
include("./src/qgplsim.ji")

n_repeat = 25
nfold = 4
tau = [0.25]
Alpha = []
Theta = []
Beta = []
Gamma = []
Theta_mave = []
Beta_mave = []
width_exp = -0.15
@threads for t in 1:4
    for k in 1:n_repeat

        index_test, index_train = nsplit_z(Z, nfold)
        alpha = []
        theta = []
        beta = []
        gamma = []
        θ_mave = []
        β_mave = []
        for k in 1:nfold
            indt, indr = index_test[k], index_train[k]
            Xr, Zr, yr = X[indr, :], Z[indr, :], y[indr] 
            Xt, Zt, yt = X[indt, :], Z[indt, :], y[indt]
            qr_model = qgplsim.model(Xr, Zr, yr, tau, width_exp)
            qgplsim.estimator(qr_model)
            push!(alpha, qr_model.alpha)
            push!(beta, qr_model.beta)
            push!(theta, qr_model.theta)
            push!(gamma, qr_model.gamma) 
            
            mave_model = semiMAVE.model(Xr, Zr, yr)
            semiMAVE.estimator(mave_model)         
            push!(β_mave, mave_model.β)
            push!(θ_mave, mave_model.θ)

        end
        alpha_, theta_, beta_, gamma_  = mean(alpha), mean(theta), mean(beta), mean(gamma)
        # beta_mave, theta_mave = mean(β_mave), mean(θ_mave)
        push!(Alpha, alpha_)
        push!(Beta, beta_)
        push!(Theta, theta_)
        push!(Gamma, gamma_)

        # push!(Beta_mave, beta_mave)
        # push!(Theta_mave, theta_mave)

    end
end
# Out:
# WARNING: replacing module semiMAVE.
# WARNING: replacing module qgplsim.

# %% [markdown]
# ## 100次蒙特卡洛模拟后各个参数的均值

# %%
alpha_, theta_, beta_, gamma_ = mean(Alpha), mean(Theta), mean(Beta), mean(Gamma)
[[:alpha, :theta] [mean(Alpha) mean(Theta)]']
# Out:
# 2×5 Matrix{Any}:
#  :alpha  -0.0395136  -0.0925013  -0.0451237   0.0394158
#  :theta   0.907774   -0.343318   -0.0516215  -0.0695164

# %%
[[:beta, :gamma] [mean(Beta) mean(Gamma)]']
# Out:
# 2×3 Matrix{Any}:
#  :beta   -0.0346136  0.0848169
#  :gamma  -0.0138741  0.601629

# %%
beta_mave, theta_mave = mean(Beta_mave), mean(Theta_mave)
beta_mave'
# Out:
# 1×2 adjoint(::Vector{Float64}) with eltype Float64:
#  -3.98784  -2.16089

# %%
theta_mave'
# Out:
# 1×4 adjoint(::Vector{Float64}) with eltype Float64:
#  -1.08248  1.24811  0.374423  -0.697243

# %% [markdown]
# 用这个参数做100次预测

# %%
rec_rmsd_qr = []
rec_rmsd_mave = []
@threads for t in 1:4
    for k in 1:n_repeat
    indr, indt = get_train_index(Z, 294)
    Xr, Zr, yr = X[indr, :], Z[indr, :], y[indr]
    Xt, Zt, yt = X[indt, :], Z[indt, :], y[indt]


    qr_model = qgplsim.model(Xr, Zr, yr, tau, width_exp)  
    qr_model.alpha, qr_model.theta, qr_model.beta, qr_model.gamma = alpha_, theta_, beta_, gamma_ 
        
    ylx = Xt * qr_model.alpha
    ylz = Zt * qr_model.beta
    gv = qgplsim.predict(qr_model, Xt, Zt)
    yp_qr = gv + ylx + ylz  
    push!(rec_rmsd_qr, rmsd(yp_qr, yt))
        
    mave_model = semiMAVE.model(Xr, Zr, yr) 
    mave_model.β, mave_model.θ = beta_mave, theta_mave   
        
    gvm, = semiMAVE.predictor(mave_model, Xt, Zt)
    yp_mave = gvm + Zt * mave_model.β
    push!(rec_rmsd_mave, rmsd(yp_mave, yt))        
    end
end

# %%
rec_rmsd_mave
# Out:
# 100-element Vector{Any}:
#  0.11525369712397729
#  0.1332473231049768
#  0.12091834358651993
#  0.12043557905489098
#  0.12091246850280765
#  0.11637808736866126
#  0.13807756545949598
#  0.12033120230450084
#  0.12787495098047974
#  0.12641501428755492
#  0.12303702083339144
#  0.1242324280623646
#  0.1212709509670903
#  ⋮
#  0.11530644623288287
#  0.14568403552984313
#  0.11761187918323017
#  0.11144949744321234
#  0.13784613019990538
#  0.12686985851747187
#  0.11699167221011902
#  0.11646253401158764
#  0.12454360843515672
#  0.13304196807318494
#  0.12285025244107782
#  0.12513698535652232

# %% [markdown]
# ## PLSIQR做100次实验后 $\sqrt{||\hat{y} - y||_2}$的分布

# %%
rec_rmsd = rec_rmsd_qr# [ rec_rmsd_qr .< 0.2 ] 
histogram(rec_rmsd, label = "rMSE")
mrmsd = round(mean(rec_rmsd), digits = 4)
std_rmsd = round(std(rec_rmsd), digits = 4)
xlabel!("mean and std of rMSE is $mrmsd, $std_rmsd")

# %%
mrmsd * Hy
# Out:
# 3.30128

# %% [markdown]
# ## SEMI-MAVE做100次实验后 $\sqrt{||\hat{y} - y||_2}$的分布

# %%
histogram(rec_rmsd_mave, label = "rMSE")
mrmsd_mave = round(mean(rec_rmsd_mave), digits = 4)
std_rmsd_mave = round(std(rec_rmsd_mave), digits = 4)

xlabel!("mean and std of rMSE is $mrmsd_mave, $std_rmsd_mave")

# %%
mrmsd_mave * Hy
# Out:
# 4.7940000000000005

# %% [markdown]
# ## 总结
#
# 夏老师的方法我可能没用调教好，精度太差了，甚至不如线性回归；
#
# 单纯就这个数据集来说PLSIQR的精度很好，速度也很快，因为无迭代，即使是qr也比夏老师的快5倍。

# %% [markdown]
# #  California Housing

# %%
include("./src/supportFunctions.ji")
include("./src/qgplsim.ji")
# include("./src/semi_mave.ji")
include("RealWorldData.ji")
using Plots
# Out:
# WARNING: replacing module qgplsim.

# %%
Xa, Za, ya = califdata(4.035) # a for all
Z, zmap = categ_binary(Za) # [:, 1]
zmap
# Out:
# 2-element Vector{Any}:
#  Dict{Any, Any}(2 => [1], 1 => [0])
#  Dict{Any, Any}("NEAR BAY" => [1, 0, 0], "INLAND" => [0, 0, 1], "NEAR OCEAN" => [0, 0, 0], "<1H OCEAN" => [0, 1, 0])

# %% [markdown]
# ## One Single Simulation

# %%
X = scaler(Xa, 1)
Hy = maximum(ya) - minimum(ya)
y = ya ./ Hy
y = y .- mean(y)
Z, zmap = categ_binary(Za) # [:, 1]

ntrain = 1000
# 原样本太大，这里选1000个

indr, indt = get_train_index(Z, ntrain)
X, Z, y = X[indr, :], Z[indr, :], y[indr]
# X_rest, Z_rest, y_rest = X[indt, :], Z[indt, :], y[indt]

width_exp = -0.2
tau = [0.75]
nfold = 4

index_test, index_train = nsplit_z(Z, nfold)
Alpha = []
Theta = []
Beta = []
Gamma = []
@threads for k in 1:nfold
    indt, indr = index_test[k], index_train[k]
    Xr, Zr, yr = X[indr, :], Z[indr, :], y[indr] 
    Xt, Zt, yt = X[indt, :], Z[indt, :], y[indt]
    carmodel = qgplsim.model(Xr, Zr, yr, tau, width_exp)
    qgplsim.estimator(carmodel)
    # qgplsim.print_model(carmodel)
    ylx = Xt * carmodel.alpha
    ylz = Zt * carmodel.beta
    gv = qgplsim.predict(carmodel, Xt, Zt)
    yp = (gv + ylx + ylz)
    push!(Alpha, carmodel.alpha)
    push!(Beta, carmodel.beta)
    push!(Theta, carmodel.theta)
    push!(Gamma, carmodel.gamma)
    println("rmse of fold $k: ", rmsd(yp, yt), "\n")
end
# Out:
# ┌ Warning: Solution may be non-unique. See http://www.econ.uiuc.edu/~roger/research/rq/FAQ #1/2.
# └ @ QuantReg /home/kyan/.julia/packages/QuantReg/8ffaW/src/fitqr.jl:69
# ┌ Warning: Solution may be non-unique. See http://www.econ.uiuc.edu/~roger/research/rq/FAQ #1/2.
# └ @ QuantReg /home/kyan/.julia/packages/QuantReg/8ffaW/src/fitqr.jl:69
# ┌ Warning: Solution may be non-unique. See http://www.econ.uiuc.edu/~roger/research/rq/FAQ #1/2.
# └ @ QuantReg /home/kyan/.julia/packages/QuantReg/8ffaW/src/fitqr.jl:69
# ┌ Warning: Solution may be non-unique. See http://www.econ.uiuc.edu/~roger/research/rq/FAQ #1/2.
# └ @ QuantReg /home/kyan/.julia/packages/QuantReg/8ffaW/src/fitqr.jl:69
# ┌ Warning: Solution may be non-unique. See http://www.econ.uiuc.edu/~roger/research/rq/FAQ #1/2.
# └ @ QuantReg /home/kyan/.julia/packages/QuantReg/8ffaW/src/fitqr.jl:69
# ┌ Warning: Solution may be non-unique. See http://www.econ.uiuc.edu/~roger/research/rq/FAQ #1/2.
# └ @ QuantReg /home/kyan/.julia/packages/QuantReg/8ffaW/src/fitqr.jl:69
# rmse of fold 4: 0.23243891126639868
#
# rmse of fold 3: 0.21566785484321058
#
# rmse of fold 1: 0.17172872024510163
#
# rmse of fold 2: 0.1636616862624073

# %% [markdown]
# 因为 y 被标准化了，这里的rmse可以看作是相对误差
#
# 这个精度很一般

# %%
alpha_, theta_, beta_, gamma_ = mean(Alpha), mean(Theta), mean(Beta), mean(Gamma)
car_model = qgplsim.model(X, Z, y, tau, width_exp)
car_model.alpha, car_model.theta, car_model.beta, car_model.gamma = alpha_, theta_, beta_, gamma_ 
ylx = X * car_model.alpha
ylz = Z * car_model.beta
gv = qgplsim.predict(car_model, X, Z)
yp = gv + ylx + ylz  
rmsd(yp, y) # * Hy
# Out:
# 0.17034416569312794

# %%
beta_
# Out:
# 4-element Vector{Float64}:
#  -0.012891773825963319
#  -0.030293953825551615
#  -0.04332752560672108
#  -0.23873850986289966

# %%
gamma_
# Out:
# 4-element Vector{Float64}:
#  -0.020185835806609286
#  -0.12978243367592257
#   0.056787886782093885
#   0.01324278948457406

# %% [markdown]
# 相当于估计的房价平均差7w多，之前也做过boston的房价预测，也一般

# %%
using LaTeXStrings
e = round(rmsd(yp, y), digits = 4)
str = string(L"||\hat{y} - y||_2 = ", "$e")
histogram(y .- yp, label = L"\hat{y} - y")
xlabel!(str)

# %%
fig = plot(layouts = (2,3))
categ, index = collection(Z)
vv = X*theta_ + Z*gamma_
for k in 1:6
    pk = fig.subplots[k]
    zk = categ[k]
    indk = index[zk]
    
    vk = vv[indk]
    
    ypk = gv[indk]
    
    yk = y[indk] - ylx[indk] - ylz[indk]

    sort_ind = sortperm(vk)

    scatter!(pk, vk, yk, label = false)
    plot!(pk, vk[sort_ind], ypk[sort_ind], width = 2, label = "g(v|z$k)")


end
fig

# %% [markdown]
# ## 总结
#
#
# 这个数据集样本量太大而且精度不如一些机器学习方法，后面就没做了，后面还是要找适合的数据集。
