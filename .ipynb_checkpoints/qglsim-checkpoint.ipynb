# %%
α = [-1, 1]
θ = [1, 1]
# γ = [0, 0]
# β = [0, -0]
γ = [1, 1]
β = [1, -0.5]

include("model.ji")
# Out:
# main (generic function with 2 methods)

# %%
n = 200
p = length(α)
@time main(γ, θ, α, β, n)
# Out:
# alpha => [0.7728514828563892, -0.5331682680215406]
# theta =>[0.8466634491836434 1.3375046997045865]
#
#   4.658305 seconds (33.97 M allocations: 3.556 GiB, 25.02% gc time)
# ([0.7728514828563892, -0.5331682680215406], [0.8466634491836434 1.3375046997045865])

# %%
Theta = zeros(100, p)
Alpha = zeros(100, p)
import Base.Threads.@threads

# %%
t = time()
@threads for i in 1:10
        for j in 1:10
    Alpha[10*(i - 1) + j, :], Theta[10*(i - 1) + j, :] = main(γ, θ, α, β, n)
    end
end
println("Computing time: ", time() - t)
println(sum(Alpha, dims = 1))
println(sum(Theta, dims = 1))
# Out:
# alpha => [0.7848797923333596, -0.4624228882741347]
# theta =>[0.7507608571028448 1.4217956697634901]
#
# alpha => [-0.6262478806031622, -0.6776955303580023]
# theta =>[-0.41342405654707376 0.6741557050384697]
#
# alpha => [0.6008535324806483, -0.6464903646572315]
# theta =>[0.8569042968338718 1.0556889187300849]
#
# alpha => [0.6920565431365575, -0.5704912679466805]
# theta =>[0.8634334885496513 1.2319230215072197]
#
# alpha => [0.8408843414663237, -0.4775327653751827]
# theta =>[0.7578888742733007 1.3883998666466157]
#
# alpha => [0.8010728151813534, -0.5371569733528045]
# theta =>[0.8408933519159089 1.3205203704350867]
#
# alpha => [-0.6439188983310923, 0.6817857310473191]
# theta =>[0.922158298557556 1.0149505909271317]
#
# alpha => [-0.648493829818228, 0.6113327586981211]
# theta =>[0.8757595983267572 1.1771051754182256]
#
# alpha => [-0.47598912911802516, 0.8212487916014313]
# theta =>[0.9347959862222595 0.675685399411728]
#
# alpha => [0.5628378022546654, -0.6907246484335988]
# theta =>[0.8686593383815064 0.9519693531266767]
#
# alpha => [0.5414930307968514, -0.7224071231301729]
# theta =>[0.8930019065217486 0.908095155140685]
#
# alpha => [0.6619036031694351, -0.6594547863405248]
# theta =>[0.9334023726944197 1.080657172016101]
#
# alpha => [-0.8066713599653509, 0.48737003485540176]
# theta =>[0.7620351661805438 1.3644975492813916]
#
# alpha => [0.7774131402504607, 0.5083802863617877]
# theta =>[-0.4642827586858209 1.0092359064711118]
#
# alpha => [0.6739399403907932, -0.4678685442878925]
# theta =>[0.7293218954873417 1.3467976458121063]
#
# alpha => [-0.41206763755376363, -0.8015283979619917]
# theta =>[-0.1615254310532184 0.4225244058655433]
#
# alpha => [0.5860443268136467, -0.7605065640154591]
# theta =>[0.9608368999247964 0.8416168727513568]
#
# alpha => [-0.6383954219904522, 0.6629723836410043]
# theta =>[0.8900054283714653 1.0410326548127273]
#
# alpha => [-0.712624432444142, -0.6486170584668984]
# theta =>[-0.4978671394261003 0.6933152290819967]
#
# alpha => [-0.7066872493965698, 0.5384875114533761]
# theta =>[0.8048340718444262 1.2722255245209597]
